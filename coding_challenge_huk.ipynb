# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.5 MB 3.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.5 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.5 MB 3.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/11.5 MB 3.4 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.5 MB 3.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.5 MB 3.4 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.5 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.5 MB 3.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.5 MB 3.4 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.5 MB 3.4 MB/s eta 0:00:02
# ...

# %%
# !pip install arff
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for arff: filename=arff-0.9-py3-none-any.whl size=4965 sha256=5ebbc3e7e2eddff0d69192633890dccf5abda680ab4db25272ba1862677ede7a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\a7\30\97\2e32fa29b02eafc957100656820b0b66f199057de8c77a1821
# Successfully built arff
# ...

# %%
import pandas as pd
import arff

# %%
data_freq = arff.load('freMTPL2freq.arff')

# %%
df_freq = pd.DataFrame(data_freq, columns=["IDpol", "ClaimNb", "Exposure", "Area", "VehPower", "VehAge", "DrivAge", "BonusMalus", "VehBrand", "VehGas", "Density", "Region"])

# %%
data_sev = arff.load('freMTPL2sev.arff')
df_sev = pd.DataFrame(data_sev, columns=["IDpol", "ClaimAmount"])

# %%
display(df_sev)
# Out:
#            IDpol  ClaimAmount
# 0         1552.0       995.20
# 1      1010996.0      1128.12
# 2      4024277.0      1851.11
# 3      4007252.0      1204.00
# 4      4046424.0      1204.00
# ...          ...          ...
# 26634  3254353.0      1200.00
# 26635  3254353.0      1800.00
# 26636  3254353.0      1000.00
# 26637  2222064.0       767.55
# 26638  2254065.0      1500.00
#
# [26639 rows x 2 columns]

# %%
display(df_freq)
# Out:
#             IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  \
# 0             1.0      1.0   0.10000  'D'       5.0     0.0     55.0
# 1             3.0      1.0   0.77000  'D'       5.0     0.0     55.0
# 2             5.0      1.0   0.75000  'B'       6.0     2.0     52.0
# 3            10.0      1.0   0.09000  'B'       7.0     0.0     46.0
# 4            11.0      1.0   0.84000  'B'       7.0     0.0     46.0
# ...           ...      ...       ...  ...       ...     ...      ...
# 678008  6114326.0      0.0   0.00274  'E'       4.0     0.0     54.0
# 678009  6114327.0      0.0   0.00274  'E'       4.0     0.0     41.0
# 678010  6114328.0      0.0   0.00274  'D'       6.0     2.0     45.0
# 678011  6114329.0      0.0   0.00274  'B'       4.0     0.0     60.0
# 678012  6114330.0      0.0   0.00274  'B'       7.0     6.0     29.0
#
#         BonusMalus VehBrand   VehGas  Density Region
# 0             50.0    'B12'  Regular   1217.0  'R82'
# ...

# %%
import pandas as pd
import arff

# %%
data_freq = arff.load('freMTPL2freq.arff')

# %%
df_freq = pd.DataFrame(data_freq, columns=["IDpol", "ClaimNb", "Exposure", "Area", "VehPower", "VehAge", "DrivAge", "BonusMalus", "VehBrand", "VehGas", "Density", "Region"])

# %%
data_sev = arff.load('freMTPL2sev.arff')
df_sev = pd.DataFrame(data_sev, columns=["IDpol", "ClaimAmount"])

# %%
df_sev.head()
# Out:
#        IDpol  ClaimAmount
# 0     1552.0       995.20
# 1  1010996.0      1128.12
# 2  4024277.0      1851.11
# 3  4007252.0      1204.00
# 4  4046424.0      1204.00

# %%
data_freq = arff.load('freMTPL2freq.arff')

# %%
df_freq = pd.DataFrame(data_freq, columns=["IDpol", "ClaimNb", "Exposure", "Area", "VehPower", "VehAge", "DrivAge", "BonusMalus", "VehBrand", "VehGas", "Density", "Region"])

# %%
df_freq.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0    1.0      1.0      0.10  'D'       5.0     0.0     55.0        50.0
# 1    3.0      1.0      0.77  'D'       5.0     0.0     55.0        50.0
# 2    5.0      1.0      0.75  'B'       6.0     2.0     52.0        50.0
# 3   10.0      1.0      0.09  'B'       7.0     0.0     46.0        50.0
# 4   11.0      1.0      0.84  'B'       7.0     0.0     46.0        50.0
#
#   VehBrand   VehGas  Density Region
# 0    'B12'  Regular   1217.0  'R82'
# 1    'B12'  Regular   1217.0  'R82'
# 2    'B12'   Diesel     54.0  'R22'
# 3    'B12'   Diesel     76.0  'R72'
# 4    'B12'   Diesel     76.0  'R72'

# %%
df_freq.describe()
# Out:
#               IDpol        ClaimNb       Exposure       VehPower  \
# count  6.780130e+05  678013.000000  678013.000000  678013.000000
# mean   2.621857e+06       0.053247       0.528750       6.454631
# std    1.641783e+06       0.240117       0.364442       2.050906
# min    1.000000e+00       0.000000       0.002732       4.000000
# 25%    1.157951e+06       0.000000       0.180000       5.000000
# 50%    2.272152e+06       0.000000       0.490000       6.000000
# 75%    4.046274e+06       0.000000       0.990000       7.000000
# max    6.114330e+06      16.000000       2.010000      15.000000
#
#               VehAge        DrivAge     BonusMalus        Density
# count  678013.000000  678013.000000  678013.000000  678013.000000
# mean        7.044265      45.499122      59.761502    1792.422405
# std         5.666232      14.137444      15.636658    3958.646564
# min         0.000000      18.000000      50.000000       1.000000
# ...

# %%
df_sev.describe()
# Out:
#               IDpol   ClaimAmount
# count  2.663900e+04  2.663900e+04
# mean   2.279864e+06  2.278536e+03
# std    1.577202e+06  2.929748e+04
# min    1.390000e+02  1.000000e+00
# 25%    1.087642e+06  6.868100e+02
# 50%    2.137413e+06  1.172000e+03
# 75%    3.180162e+06  1.228080e+03
# max    6.113971e+06  4.075401e+06

# %%
df_freq.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678013 entries, 0 to 678012
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IDpol       678013 non-null  float64
#  1   ClaimNb     678013 non-null  float64
#  2   Exposure    678013 non-null  float64
#  3   Area        678013 non-null  object
#  4   VehPower    678013 non-null  float64
#  5   VehAge      678013 non-null  float64
#  6   DrivAge     678013 non-null  float64
#  7   BonusMalus  678013 non-null  float64
#  8   VehBrand    678013 non-null  object
#  9   VehGas      678013 non-null  object
#  10  Density     678013 non-null  float64
#  11  Region      678013 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 62.1+ MB

# %%
df_sev.duplicated().sum()
# Out:
# np.int64(255)

# %%
duplicate_rows_sev = df_sev.duplicated()
if 'TRUE' in duplicate_rows_sev:
    df_sev = df_sev[~duplicate_rows_sev]

# %%
df_sev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26639 entries, 0 to 26638
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   IDpol        26639 non-null  float64
#  1   ClaimAmount  26639 non-null  float64
# dtypes: float64(2)
# memory usage: 416.4 KB

# %%
duplicate_rows_freq = df_freq.duplicated()
if 'TRUE' in duplicate_rows_freq:
    df_freq = df_freq[~duplicate_rows_freq]

# %%
df_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678013 entries, 0 to 678012
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IDpol       678013 non-null  float64
#  1   ClaimNb     678013 non-null  float64
#  2   Exposure    678013 non-null  float64
#  3   Area        678013 non-null  object
#  4   VehPower    678013 non-null  float64
#  5   VehAge      678013 non-null  float64
#  6   DrivAge     678013 non-null  float64
#  7   BonusMalus  678013 non-null  float64
#  8   VehBrand    678013 non-null  object
#  9   VehGas      678013 non-null  object
#  10  Density     678013 non-null  float64
#  11  Region      678013 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 62.1+ MB

# %%
if 'TRUE' in duplicate_rows_freq:
    print(duplicate_rows_freq.index())

# %%
df_freq.isnull().sum()
# Out:
# IDpol         0
# ClaimNb       0
# Exposure      0
# Area          0
# VehPower      0
# VehAge        0
# DrivAge       0
# BonusMalus    0
# VehBrand      0
# VehGas        0
# Density       0
# Region        0
# dtype: int64

# %%
df_sev.isnull().sum()
# Out:
# IDpol          0
# ClaimAmount    0
# dtype: int64

# %%
ClaimAmountSums = df_sev.groupby('IDpol')['ClaimAmount'].sum()

# %%
ClaimAmountSums
# Out:
# IDpol
# 139.0          303.00
# 190.0         1981.84
# 414.0         1456.55
# 424.0        10834.00
# 463.0         3986.67
#                ...
# 6113521.0     1324.40
# 6113793.0     1769.88
# 6113817.0     1288.28
# 6113834.0    12230.40
# 6113971.0     1452.00
# Name: ClaimAmount, Length: 24950, dtype: float64

# %%
ClaimAmountSums.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 24950 entries, 139.0 to 6113971.0
# Series name: ClaimAmount
# Non-Null Count  Dtype
# --------------  -----
# 24950 non-null  float64
# dtypes: float64(1)
# memory usage: 389.8 KB

# %%
df = pd.merge(df_freq, ClaimAmountSums, on = "IDpol", how = "outer")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678019 entries, 0 to 678018
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   IDpol        678019 non-null  float64
#  1   ClaimNb      678013 non-null  float64
#  2   Exposure     678013 non-null  float64
#  3   Area         678013 non-null  object
#  4   VehPower     678013 non-null  float64
#  5   VehAge       678013 non-null  float64
#  6   DrivAge      678013 non-null  float64
#  7   BonusMalus   678013 non-null  float64
#  8   VehBrand     678013 non-null  object
#  9   VehGas       678013 non-null  object
#  10  Density      678013 non-null  float64
#  11  Region       678013 non-null  object
#  12  ClaimAmount  24950 non-null   float64
# dtypes: float64(9), object(4)
# memory usage: 67.2+ MB

# %%
df.isnull().sum()
# Out:
# IDpol               0
# ClaimNb             6
# Exposure            6
# Area                6
# VehPower            6
# VehAge              6
# DrivAge             6
# BonusMalus          6
# VehBrand            6
# VehGas              6
# Density             6
# Region              6
# ClaimAmount    653069
# dtype: int64

# %%
df = pd.merge(df_freq, ClaimAmountSums, on = "IDpol", how = "outer")

# %%
df_copy = df.dropna(thresh = 3)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 0 to 678018
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   IDpol        678013 non-null  float64
#  1   ClaimNb      678013 non-null  float64
#  2   Exposure     678013 non-null  float64
#  3   Area         678013 non-null  object
#  4   VehPower     678013 non-null  float64
#  5   VehAge       678013 non-null  float64
#  6   DrivAge      678013 non-null  float64
#  7   BonusMalus   678013 non-null  float64
#  8   VehBrand     678013 non-null  object
#  9   VehGas       678013 non-null  object
#  10  Density      678013 non-null  float64
#  11  Region       678013 non-null  object
#  12  ClaimAmount  24944 non-null   float64
# dtypes: float64(9), object(4)
# memory usage: 72.4+ MB

# %%
df_copy.loc[df_copy.ClaimAmount != df_copy.ClaimAmount.isnull(), "CAdivExp"] = df_copy["ClaimAmount"]/df_copy["Exposure"]

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 0 to 678018
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   IDpol        678013 non-null  float64
#  1   ClaimNb      678013 non-null  float64
#  2   Exposure     678013 non-null  float64
#  3   Area         678013 non-null  object
#  4   VehPower     678013 non-null  float64
#  5   VehAge       678013 non-null  float64
#  6   DrivAge      678013 non-null  float64
#  7   BonusMalus   678013 non-null  float64
#  8   VehBrand     678013 non-null  object
#  9   VehGas       678013 non-null  object
#  10  Density      678013 non-null  float64
#  11  Region       678013 non-null  object
#  12  ClaimAmount  24944 non-null   float64
#  13  CAdivExp     24944 non-null   float64
# dtypes: float64(10), object(4)
# memory usage: 77.6+ MB

# %%
df_copy.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0    1.0      1.0      0.10  'D'       5.0     0.0     55.0        50.0
# 1    3.0      1.0      0.77  'D'       5.0     0.0     55.0        50.0
# 2    5.0      1.0      0.75  'B'       6.0     2.0     52.0        50.0
# 3   10.0      1.0      0.09  'B'       7.0     0.0     46.0        50.0
# 4   11.0      1.0      0.84  'B'       7.0     0.0     46.0        50.0
#
#   VehBrand   VehGas  Density Region  ClaimAmount  CAdivExp
# 0    'B12'  Regular   1217.0  'R82'          NaN       NaN
# 1    'B12'  Regular   1217.0  'R82'          NaN       NaN
# 2    'B12'   Diesel     54.0  'R22'          NaN       NaN
# 3    'B12'   Diesel     76.0  'R72'          NaN       NaN
# 4    'B12'   Diesel     76.0  'R72'          NaN       NaN

# %%
df_copy.describe()
# Out:
#               IDpol        ClaimNb       Exposure       VehPower  \
# count  6.780130e+05  678013.000000  678013.000000  678013.000000
# mean   2.621857e+06       0.053247       0.528750       6.454631
# std    1.641783e+06       0.240117       0.364442       2.050906
# min    1.000000e+00       0.000000       0.002732       4.000000
# 25%    1.157951e+06       0.000000       0.180000       5.000000
# 50%    2.272152e+06       0.000000       0.490000       6.000000
# 75%    4.046274e+06       0.000000       0.990000       7.000000
# max    6.114330e+06      16.000000       2.010000      15.000000
#
#               VehAge        DrivAge     BonusMalus        Density  \
# count  678013.000000  678013.000000  678013.000000  678013.000000
# mean        7.044265      45.499122      59.761502    1792.422405
# std         5.666232      14.137444      15.636658    3958.646564
# min         0.000000      18.000000      50.000000       1.000000
# ...

# %%
df = df.dropna(thresh = 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 0 to 678018
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   IDpol        678013 non-null  float64
#  1   ClaimNb      678013 non-null  float64
#  2   Exposure     678013 non-null  float64
#  3   Area         678013 non-null  object
#  4   VehPower     678013 non-null  float64
#  5   VehAge       678013 non-null  float64
#  6   DrivAge      678013 non-null  float64
#  7   BonusMalus   678013 non-null  float64
#  8   VehBrand     678013 non-null  object
#  9   VehGas       678013 non-null  object
#  10  Density      678013 non-null  float64
#  11  Region       678013 non-null  object
#  12  ClaimAmount  24944 non-null   float64
# dtypes: float64(9), object(4)
# memory usage: 72.4+ MB

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0    1.0      1.0      0.10  'D'       5.0     0.0     55.0        50.0
# 1    3.0      1.0      0.77  'D'       5.0     0.0     55.0        50.0
# 2    5.0      1.0      0.75  'B'       6.0     2.0     52.0        50.0
# 3   10.0      1.0      0.09  'B'       7.0     0.0     46.0        50.0
# 4   11.0      1.0      0.84  'B'       7.0     0.0     46.0        50.0
#
#   VehBrand   VehGas  Density Region  ClaimAmount
# 0    'B12'  Regular   1217.0  'R82'          0.0
# 1    'B12'  Regular   1217.0  'R82'          0.0
# 2    'B12'   Diesel     54.0  'R22'          0.0
# 3    'B12'   Diesel     76.0  'R72'          0.0
# 4    'B12'   Diesel     76.0  'R72'          0.0

# %%
df.loc[df.ClaimAmount != df.ClaimAmount.isnull(), "CAdivExp"] = df["ClaimAmount"]/df["Exposure"]

# %%
df.describe()
# Out:
#               IDpol        ClaimNb       Exposure       VehPower  \
# count  6.780130e+05  678013.000000  678013.000000  678013.000000
# mean   2.621857e+06       0.053247       0.528750       6.454631
# std    1.641783e+06       0.240117       0.364442       2.050906
# min    1.000000e+00       0.000000       0.002732       4.000000
# 25%    1.157951e+06       0.000000       0.180000       5.000000
# 50%    2.272152e+06       0.000000       0.490000       6.000000
# 75%    4.046274e+06       0.000000       0.990000       7.000000
# max    6.114330e+06      16.000000       2.010000      15.000000
#
#               VehAge        DrivAge     BonusMalus        Density  \
# count  678013.000000  678013.000000  678013.000000  678013.000000
# mean        7.044265      45.499122      59.761502    1792.422405
# std         5.666232      14.137444      15.636658    3958.646564
# min         0.000000      18.000000      50.000000       1.000000
# ...

# %%
df["ClaimAmount"].sum()
# Out:
# np.float64(59909216.49999999)

# %%
df_copy["ClaimAmount"].sum()
# Out:
# np.float64(59909216.49999999)

# %%
df.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0    1.0      1.0      0.10  'D'       5.0     0.0     55.0        50.0
# 1    3.0      1.0      0.77  'D'       5.0     0.0     55.0        50.0
# 2    5.0      1.0      0.75  'B'       6.0     2.0     52.0        50.0
# 3   10.0      1.0      0.09  'B'       7.0     0.0     46.0        50.0
# 4   11.0      1.0      0.84  'B'       7.0     0.0     46.0        50.0
#
#   VehBrand   VehGas  Density Region  ClaimAmount  CAdivExp
# 0    'B12'  Regular   1217.0  'R82'          0.0       NaN
# 1    'B12'  Regular   1217.0  'R82'          0.0       NaN
# 2    'B12'   Diesel     54.0  'R22'          0.0       NaN
# 3    'B12'   Diesel     76.0  'R72'          0.0       NaN
# 4    'B12'   Diesel     76.0  'R72'          0.0       NaN

# %%
df = df.fillna(0)

# %%
df.describe()
# Out:
#               IDpol        ClaimNb       Exposure       VehPower  \
# count  6.780130e+05  678013.000000  678013.000000  678013.000000
# mean   2.621857e+06       0.053247       0.528750       6.454631
# std    1.641783e+06       0.240117       0.364442       2.050906
# min    1.000000e+00       0.000000       0.002732       4.000000
# 25%    1.157951e+06       0.000000       0.180000       5.000000
# 50%    2.272152e+06       0.000000       0.490000       6.000000
# 75%    4.046274e+06       0.000000       0.990000       7.000000
# max    6.114330e+06      16.000000       2.010000      15.000000
#
#               VehAge        DrivAge     BonusMalus        Density  \
# count  678013.000000  678013.000000  678013.000000  678013.000000
# mean        7.044265      45.499122      59.761502    1792.422405
# std         5.666232      14.137444      15.636658    3958.646564
# min         0.000000      18.000000      50.000000       1.000000
# ...

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['AreaEncoded'] = encoder.fit_transform(df['Area'])

# %%
df.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0    1.0      1.0      0.10  'D'       5.0     0.0     55.0        50.0
# 1    3.0      1.0      0.77  'D'       5.0     0.0     55.0        50.0
# 2    5.0      1.0      0.75  'B'       6.0     2.0     52.0        50.0
# 3   10.0      1.0      0.09  'B'       7.0     0.0     46.0        50.0
# 4   11.0      1.0      0.84  'B'       7.0     0.0     46.0        50.0
#
#   VehBrand   VehGas  Density Region  ClaimAmount  CAdivExp  AreaEncoded
# 0    'B12'  Regular   1217.0  'R82'          0.0       0.0            3
# 1    'B12'  Regular   1217.0  'R82'          0.0       0.0            3
# 2    'B12'   Diesel     54.0  'R22'          0.0       0.0            1
# 3    'B12'   Diesel     76.0  'R72'          0.0       0.0            1
# 4    'B12'   Diesel     76.0  'R72'          0.0       0.0            1

# %%
df['VehBrandEncoded'] = encoder.fit_transform(df['VehBrand']) 
df['VehGasEncoded'] = encoder.fit_transform(df['VehGas'])

# %%
df.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0    1.0      1.0      0.10  'D'       5.0     0.0     55.0        50.0
# 1    3.0      1.0      0.77  'D'       5.0     0.0     55.0        50.0
# 2    5.0      1.0      0.75  'B'       6.0     2.0     52.0        50.0
# 3   10.0      1.0      0.09  'B'       7.0     0.0     46.0        50.0
# 4   11.0      1.0      0.84  'B'       7.0     0.0     46.0        50.0
#
#   VehBrand   VehGas  Density Region  ClaimAmount  CAdivExp  AreaEncoded  \
# 0    'B12'  Regular   1217.0  'R82'          0.0       0.0            3
# 1    'B12'  Regular   1217.0  'R82'          0.0       0.0            3
# 2    'B12'   Diesel     54.0  'R22'          0.0       0.0            1
# 3    'B12'   Diesel     76.0  'R72'          0.0       0.0            1
# 4    'B12'   Diesel     76.0  'R72'          0.0       0.0            1
#
#    VehBrandEncoded  VehGasEncoded
# 0                3              1
# ...

# %%
df['RegionEncoded'] = encoder.fit_transform(df['Region'])

# %%
df.head()
# Out:
#    IDpol  ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# 0    1.0      1.0      0.10  'D'       5.0     0.0     55.0        50.0
# 1    3.0      1.0      0.77  'D'       5.0     0.0     55.0        50.0
# 2    5.0      1.0      0.75  'B'       6.0     2.0     52.0        50.0
# 3   10.0      1.0      0.09  'B'       7.0     0.0     46.0        50.0
# 4   11.0      1.0      0.84  'B'       7.0     0.0     46.0        50.0
#
#   VehBrand   VehGas  Density Region  ClaimAmount  CAdivExp  AreaEncoded  \
# 0    'B12'  Regular   1217.0  'R82'          0.0       0.0            3
# 1    'B12'  Regular   1217.0  'R82'          0.0       0.0            3
# 2    'B12'   Diesel     54.0  'R22'          0.0       0.0            1
# 3    'B12'   Diesel     76.0  'R72'          0.0       0.0            1
# 4    'B12'   Diesel     76.0  'R72'          0.0       0.0            1
#
#    VehBrandEncoded  VehGasEncoded  RegionEncoded
# 0                3              1             17
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 0 to 678018
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   IDpol            678013 non-null  float64
#  1   ClaimNb          678013 non-null  float64
#  2   Exposure         678013 non-null  float64
#  3   Area             678013 non-null  object
#  4   VehPower         678013 non-null  float64
#  5   VehAge           678013 non-null  float64
#  6   DrivAge          678013 non-null  float64
#  7   BonusMalus       678013 non-null  float64
#  8   VehBrand         678013 non-null  object
#  9   VehGas           678013 non-null  object
#  10  Density          678013 non-null  float64
#  11  Region           678013 non-null  object
#  12  ClaimAmount      678013 non-null  float64
#  13  CAdivExp         678013 non-null  float64
#  14  AreaEncoded      678013 non-null  int64
#  15  VehBrandEncoded  678013 non-null  int64
# ...

# %%
X = df.drop(['Area', 'VehBrand', 'VehGas', 'Region', 'CAdivExp', 'IDpol', 'ClaimNb', 'Exposure'],axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 0 to 678018
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VehPower         678013 non-null  float64
#  1   VehAge           678013 non-null  float64
#  2   DrivAge          678013 non-null  float64
#  3   BonusMalus       678013 non-null  float64
#  4   Density          678013 non-null  float64
#  5   ClaimAmount      678013 non-null  float64
#  6   AreaEncoded      678013 non-null  int64
#  7   VehBrandEncoded  678013 non-null  int64
#  8   VehGasEncoded    678013 non-null  int64
#  9   RegionEncoded    678013 non-null  int64
# dtypes: float64(6), int64(4)
# memory usage: 73.0 MB

# %%
y = df["CAdivExp"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=1)

# %%
from sklearn import linear_model

model = linear_model.TweedieRegressor(power=1.5, solver='newton-cholesky',max_iter=1000).fit(X_train,y_train)
model.score(X_train,y_train)
# Out:
# np.float64(0.15552674075134)

# %%
#predict
y_pred = model.predict(X_test)

# %%
#Evaluation 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print("Mean Square Error", mean_squared_error(y_pred,y_test))
print("Mean Absolute Error", mean_absolute_error(y_pred,y_test))
# Out:
# Mean Square Error 662679947.2375269
# Mean Absolute Error 620.2730120385127

# %%
from sklearn.metrics import d2_tweedie_score

d2_tweedie_score(y_test, y_pred, power=1.5)
# Out:
# np.float64(0.11558705891359788)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 0 to 678018
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   IDpol            678013 non-null  float64
#  1   ClaimNb          678013 non-null  float64
#  2   Exposure         678013 non-null  float64
#  3   Area             678013 non-null  object
#  4   VehPower         678013 non-null  float64
#  5   VehAge           678013 non-null  float64
#  6   DrivAge          678013 non-null  float64
#  7   BonusMalus       678013 non-null  float64
#  8   VehBrand         678013 non-null  object
#  9   VehGas           678013 non-null  object
#  10  Density          678013 non-null  float64
#  11  Region           678013 non-null  object
#  12  ClaimAmount      678013 non-null  float64
#  13  CAdivExp         678013 non-null  float64
#  14  AreaEncoded      678013 non-null  int64
#  15  VehBrandEncoded  678013 non-null  int64
# ...

# %%
df_copy = df.drop(['Area', 'VehBrand', 'VehGas', 'Region'],axis=1)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 0 to 678018
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   IDpol            678013 non-null  float64
#  1   ClaimNb          678013 non-null  float64
#  2   Exposure         678013 non-null  float64
#  3   VehPower         678013 non-null  float64
#  4   VehAge           678013 non-null  float64
#  5   DrivAge          678013 non-null  float64
#  6   BonusMalus       678013 non-null  float64
#  7   Density          678013 non-null  float64
#  8   ClaimAmount      678013 non-null  float64
#  9   CAdivExp         678013 non-null  float64
#  10  AreaEncoded      678013 non-null  int64
#  11  VehBrandEncoded  678013 non-null  int64
#  12  VehGasEncoded    678013 non-null  int64
#  13  RegionEncoded    678013 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 93.7 MB

# %%
df_copy.corr(method='pearson')
# Out:
#                     IDpol   ClaimNb  Exposure  VehPower    VehAge   DrivAge  \
# IDpol            1.000000 -0.127949 -0.160152  0.048610 -0.156919  0.063703
# ClaimNb         -0.127949  1.000000  0.068909 -0.004259 -0.021768  0.011392
# Exposure        -0.160152  0.068909  1.000000 -0.045259  0.151554  0.171873
# VehPower         0.048610 -0.004259 -0.045259  1.000000 -0.006001  0.030108
# VehAge          -0.156919 -0.021768  0.151554 -0.006001  1.000000 -0.059213
# DrivAge          0.063703  0.011392  0.171873  0.030108 -0.059213  1.000000
# BonusMalus      -0.005595  0.050544 -0.183018 -0.075895  0.079923 -0.479966
# Density          0.070759  0.010754 -0.071085  0.042901 -0.090428 -0.004700
# ClaimAmount     -0.003894  0.071185  0.002244  0.001275  0.002321 -0.003663
# CAdivExp        -0.002802  0.048224 -0.008517  0.000183  0.001413 -0.005839
# AreaEncoded      0.069722  0.013533 -0.121939  0.003177 -0.104530 -0.045180
# ...

# %%
y_pred.mean()
# Out:
# np.float64(311.98643248565344)

# %%
df["CAdivExp"].mean()
# Out:
# np.float64(383.2607653923773)

# %%
df.ClaimAmount.quantile(0.99)
# Out:
# np.float64(1253.3288)

# %%
df.ClaimAmount.quantile(0.995)
# Out:
# np.float64(2408.0)

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/7.8 MB 3.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/7.8 MB 3.4 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/7.8 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/7.8 MB 3.4 MB/s eta 0:00:02
#    --------------------- ------------------ 4.2/7.8 MB 3.4 MB/s eta 0:00:02
#    ------------------------- -------------- 5.0/7.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.8 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 3.4 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['DrivAge'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['BonusMalus'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
